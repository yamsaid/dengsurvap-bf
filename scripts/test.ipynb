# %%
from dengsurvab import AppiClient

# %%
from dengsurvab.client import AppiClient
cl = AppiClient.from_env()
cl.authenticate(email="yamsaid74@gmail.com", password="1122Aa")
# Out:
# {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJzYWlkIiwiZXhwIjoxNzUyMjc3MzE0fQ.x4S_RCkc2UrjTt8gyPbSGQfgxH5Ry3aXIZ7kke-hDYc',
#  'token_type': 'bearer',
#  'user': {'id': 2,
#   'username': 'said',
#   'email': 'yamsaid74@gmail.com',
#   'role': 'admin',
#   'first_name': 'Said',
#   'last_name': 'YAMEOGO'}}

# %%
df = cl.data(date_debut="2025-01-01", date_fin="2025-07-07")

# %%
df.head()
# Out:
#     district   idCas date_consultation  region  age serotype          issue  \
# 0  DS Baskuy  131495        2025-02-08  Centre    9    DENV3       Inconnue
# 1  DS Baskuy  131496        2025-02-02  Centre   32    DENV3       Inconnue
# 2  DS Baskuy  131575        2025-05-16  Centre   31    DENV3          Guéri
# 3  DS Baskuy  131576        2025-05-07  Centre   20    DENV3       Inconnue
# 4  DS Baskuy  131497        2025-05-02  Centre   21    DENV2  En traitement
#
#     sexe resultat_test hospitalise  id_source
# 0  Femme       Négatif         Non          2
# 1  Femme       Négatif         Non          2
# 2  Femme       Négatif         Non          2
# 3  Femme       Négatif         Non          2
# 4  Femme       Négatif         Non          2

# %%
df.hospitalise.value_counts()
# Out:
# hospitalise
# Non    94412
# Oui    37181
# Name: count, dtype: int64

# %%
cl.resumer(df)
# Out:
# ==============================
#   🗂️  Informations générales
# ==============================
# 📅 Période de couverture : 2025-01-01 → 2025-07-06  (⏳ 186 jours)
# 🧾 Nombre d'observations : 131593
# 🗺️  Nombre de régions : 2
# 🏘️  Nombre de districts : 13
# 🕒 Dernière mise à jour : 2025-07-06
#
# === Variables quantitatives ===
# |           |    Min |    Max |      Moyenne |    Ecart-type |     Q1 |   Médiane |     Q3 |   manquantes |
# |-----------|--------|--------|--------------|---------------|--------|-----------|--------|--------------|
# | idCas     | 131495 | 263087 | 197291       | 37987.8       | 164393 |    197291 | 230189 |            0 |
# | age       |      0 |     86 |     25.1352  |    14.0057    |     15 |        25 |     35 |            0 |
# | id_source |      2 |      3 |      2.00075 |     0.0274182 |      2 |         2 |      2 |            0 |
# | annee     |   2025 |   2025 |   2025       |     0         |   2025 |      2025 |   2025 |            0 |
# | mois      |      1 |      7 |      3.5747  |     1.49915   |      2 |         4 |      5 |            0 |
#
# === Variables qualitatives ===
# | Variable        | Type     | Mode        |   Nb modalités |   Manquantes |
# |-----------------|----------|-------------|----------------|--------------|
# | district        | object   | DS Bogodogo |             13 |            0 |
# | region          | object   | Centre      |              2 |            0 |
# | serotype        | object   | DENV2       |              2 |            0 |
# | issue           | object   | Inconnue    |              4 |            0 |
# | sexe            | object   | Femme       |              2 |            0 |
# | resultat_test   | object   | Positif     |              2 |            0 |
# | hospitalisation | object   | Non         |              2 |            0 |
# | tranche_age     | category | 20-29       |              9 |            0 |

# %%
cl.timeout = 300

# %%
cl.graph_desc(df, )

# %%
help(cl.graph_desc)
# Out:
# Help on method graph_desc in module dengsurvab.client:
#
# graph_desc(*args, **kwargs) method of dengsurvab.client.AppiClient instance
#     Visualisation descriptive de la base (camemberts, barres, histogrammes).
#     (Remplace l'ancienne méthode resume_display)
#
#     Voir : SyntheseBase.graph_desc pour la liste complète des paramètres et options.
#
#     Exemple :
#         client.graph_desc(date_debut="2024-01-01", date_fin="2024-12-31")

# %%
from dengsurvab.analytics import SyntheseBase as synth

# %%
#client = AppiClient()
synth = synth(client=cl)

# %%
df = cl.data( page=1, limit=5000)

# %%
df.shape

# %%
synth.evolution(df, frequence="M", taux_croissance=True)
# Out:
# c:\Users\USER\data_analyse_env\Lib\site-packages\dengsurvab\analytics.py:936: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend(title=by[0] if by else cible.title(), fontsize=10, framealpha=0.9)
# c:\Users\USER\data_analyse_env\Lib\site-packages\dengsurvab\analytics.py:957: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2.legend(title=by[0] if by else cible.title(), fontsize=10, framealpha=0.9)
# c:\Users\USER\data_analyse_env\Lib\site-packages\dengsurvab\analytics.py:936: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend(title=by[0] if by else cible.title(), fontsize=10, framealpha=0.9)
# c:\Users\USER\data_analyse_env\Lib\site-packages\dengsurvab\analytics.py:957: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2.legend(title=by[0] if by else cible.title(), fontsize=10, framealpha=0.9)
# c:\Users\USER\data_analyse_env\Lib\site-packages\dengsurvab\analytics.py:936: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend(title=by[0] if by else cible.title(), fontsize=10, framealpha=0.9)
# c:\Users\USER\data_analyse_env\Lib\site-packages\dengsurvab\analytics.py:957: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2.legend(title=by[0] if by else cible.title(), fontsize=10, framealpha=0.9)

# %%
synth.graph_desc(df,max_modalites=15, boxplot_age=True)

# %%
synth.resumer(df,detail=True)
# Out:
# ==============================
#   🗂️  Informations générales
# ==============================
# 📅 Période de couverture : 2024-01-01 → 2024-12-28  (⏳ 362 jours)
# 🧾 Nombre d'observations : 5000
# 🗺️  Nombre de régions : 1
# 🏘️  Nombre de districts : 1
# 🕒 Dernière mise à jour : 2025-07-06
#
# === Variables quantitatives ===
# |           |   Min |   Max |   Moyenne |   Ecart-type |      Q1 |   Médiane |      Q3 |   manquantes |
# |-----------|-------|-------|-----------|--------------|---------|-----------|---------|--------------|
# | idCas     |     1 |  5000 | 2500.5    |   1443.52    | 1250.75 |    2500.5 | 3750.25 |            0 |
# | age       |     0 |    87 |   25.05   |     14.0851  |   14    |      24   |   34    |            0 |
# | id_source |     1 |     1 |    1      |      0       |    1    |       1   |    1    |            0 |
# | annee     |  2024 |  2024 | 2024      |      0       | 2024    |    2024   | 2024    |            0 |
# | mois      |     1 |    12 |    6.2558 |      2.98385 |    5    |       6   |    8    |            0 |
#
# === Variables qualitatives ===
# | Variable        | Type     | Mode      |   Nb modalités |   Manquantes |
# |-----------------|----------|-----------|----------------|--------------|
# | district        | object   | DS Baskuy |              1 |            0 |
# | region          | object   | Centre    |              1 |            0 |
# | serotype        | object   | DENV2     |              2 |            0 |
# | issue           | object   | Guéri     |              4 |            0 |
# | sexe            | object   | Homme     |              2 |            0 |
# | resultat_test   | object   | Positif   |              2 |            0 |
# | hospitalisation | object   | Non       |              2 |            0 |
# | tranche_age     | category | 20-29     |              9 |            0 |
#
# === Détail des modalités (optionnel) ===
# district :
# |    | N         |   count |
# |----|-----------|---------|
# |  0 | DS Baskuy |    5000 |
# region :
# |    | N      |   count |
# |----|--------|---------|
# |  0 | Centre |    5000 |
# serotype :
# |    | N     |   count |
# |----|-------|---------|
# |  0 | DENV2 |    2546 |
# |  1 | DENV3 |    2454 |
# issue :
# |    | N             |   count |
# |----|---------------|---------|
# |  0 | Inconnue      |    1646 |
# |  1 | Guéri         |    1646 |
# |  2 | En traitement |    1627 |
# |  3 | Décédé        |      81 |
# sexe :
# |    | N     |   count |
# |----|-------|---------|
# |  0 | Homme |    2512 |
# |  1 | Femme |    2488 |
# resultat_test :
# |    | N       |   count |
# |----|---------|---------|
# |  0 | Positif |    2639 |
# |  1 | Négatif |    2361 |
# hospitalisation :
# |    | N   |   count |
# |----|-----|---------|
# |  0 | Non |    3567 |
# |  1 | Oui |    1433 |
# tranche_age :
# |    | N     |   count |
# |----|-------|---------|
# |  0 | 20-29 |    1297 |
# |  1 | 10-19 |    1112 |
# |  2 | 30-39 |    1006 |
# |  3 | 0-9   |     766 |
# |  4 | 40-49 |     571 |
# |  5 | 50-59 |     206 |
# |  6 | 60-69 |      32 |
# |  7 | 70-79 |       9 |
# |  8 | 80+   |       1 |

# %%
help(cl)
# Out:
# Help on AppiClient in module dengsurvab.client object:
#
# class AppiClient(builtins.object)
#  |  AppiClient(base_url: str = 'https://api-bf-dengue-survey-production.up.railway.app/', api_key: Optional[str] = None, timeout: int = 30, retry_attempts: int = 3, retry_delay: float = 1.0, debug: bool = False)
#  |
#  |  Client principal pour l'API de surveillance de la dengue Appi.
#  |
#  |  Cette classe fournit une interface complète pour accéder aux données
#  |  épidémiologiques, gérer les alertes et effectuer des analyses.
#  |
#  |  Methods defined here:
#  |
#  |  __enter__(self)
#  |      Support du context manager.
#  |
#  |  __exit__(self, exc_type, exc_val, exc_tb)
#  |      Nettoyage lors de la sortie du context manager.
#  |
#  |  __init__(self, base_url: str = 'https://api-bf-dengue-survey-production.up.railway.app/', api_key: Optional[str] = None, timeout: int = 30, retry_attempts: int = 3, retry_delay: float = 1.0, debug: bool = False)
#  |      Initialise le client Appi.
#  |
#  |      Args:
#  |          base_url: URL de base de l'API
#  |          api_key: Clé API optionnelle
#  |          timeout: Timeout des requêtes en secondes
#  |          retry_attempts: Nombre de tentatives en cas d'échec
#  |          retry_delay: Délai entre les tentatives en secondes
#  |          debug: Mode debug pour les logs détaillés
#  |
#  |  add_cas_dengue(self, cas_list: List[dengsurvab.models.ValidationCasDengue]) -> Dict[str, Any]
#  |      Ajoute une liste de cas de dengue.
#  |
#  |      Args:
#  |          cas_list: Liste des cas à ajouter
#  |
#  |      Returns:
#  |          Résultat de l'ajout
#  |
#  |  alertes(self, limit: int = 100, severity: Optional[str] = None, status: Optional[str] = None) -> pandas.core.frame.DataFrame
#  |      Exporte les alertes dans différents formats.
#  |
#  |      Args:
#  |          format: Format d'export (csv, json, xlsx)
#  |          limit: Nombre maximum d'alertes
#  |          severity: Sévérité
#  |          status: Statut
#  |
#  |      Returns:
#  |          Alertes exportées en bytes
#  |
#  |  alertes_to_file(self, filepath: Optional[str] = None, limit: int = 100, severity: Optional[str] = None, status: Optional[str] = None, format: str = 'csv') -> bool
#  |      Sauvegarde les alertes dans un fichier.
#  |
#  |      Args:
#  |          filepath: Chemin du fichier de sortie
#  |          limit: Nombre maximum d'alertes
#  |          severity: Sévérité
#  |          status: Statut
#  |          format: Format de sortie (csv, json, xlsx)
#  |
#  |      Returns:
#  |          True si la sauvegarde a réussi
#  |
#  |  authenticate(self, email: str, password: str) -> Dict[str, Any]
#  |      Authentifie l'utilisateur et récupère un token JWT.
#  |
#  |      Args:
#  |          email: Adresse email
#  |          password: Mot de passe
#  |
#  |      Returns:
#  |          Informations d'authentification
#  |
#  |      Raises:
#  |          AuthenticationError: En cas d'échec d'authentification
#  |
#  |  calculate_rates(self, date_debut: str, date_fin: str, region: Optional[str] = None, district: Optional[str] = None) -> pandas.core.frame.DataFrame
#  |      Calcule les taux épidémiologiques et retourne un DataFrame à une ligne.
#  |
#  |      Args:
#  |          date_debut: Date de début
#  |          date_fin: Date de fin
#  |          region: Région
#  |          district: District
#  |
#  |      Returns:
#  |          DataFrame à une ligne avec les taux calculés et les totaux
#  |
#  |  clear_cache(self) -> None
#  |      Vide le cache des requêtes.
#  |
#  |  configurer_seuils(self, **kwargs) -> Dict[str, Any]
#  |      Configure les seuils d'alerte.
#  |
#  |      Args:
#  |          **kwargs: Paramètres de configuration
#  |
#  |      Returns:
#  |          Résultat de la configuration
#  |
#  |  data(self, date_debut: Optional[str] = None, date_fin: Optional[str] = None, region: Optional[str] = None, district: Optional[str] = None, limit: Optional[int] = None, page: Optional[int] = None, full: bool = False) -> pandas.core.frame.DataFrame
#  |      Récupère les données de dengue sous forme de DataFrame.
#  |
#  |      Args:
#  |          date_debut: Date de début (format YYYY-MM-DD)
#  |          date_fin: Date de fin (format YYYY-MM-DD)
#  |          region: Région à filtrer
#  |          district: District à filtrer
#  |          limit: Nombre maximum de résultats
#  |          page: Page à récupérer (pour la pagination)
#  |          full: Si True, récupère toute la base (pagination automatique)
#  |
#  |      Returns:
#  |          DataFrame avec les données de dengue
#  |
#  |  detect_anomalies(self, data: pandas.core.frame.DataFrame, method: str = 'zscore', columns: Optional[List[str]] = None) -> pandas.core.frame.DataFrame
#  |      Détecte les anomalies dans les données de dengue.
#  |
#  |      Cette fonction analyse les données pour identifier des valeurs anormales
#  |      qui pourraient indiquer des situations épidémiologiques préoccupantes.
#  |
#  |      Args:
#  |          data: DataFrame avec les données à analyser
#  |          method: Méthode de détection ("zscore", "iqr", "isolation_forest")
#  |          columns: Colonnes à analyser (par défaut: colonnes numériques)
#  |
#  |      Returns:
#  |          DataFrame avec les données originales et les colonnes d'anomalies ajoutées
#  |
#  |      Raises:
#  |          AnalysisError: En cas d'erreur lors de la détection
#  |
#  |  donnees_par_periode(self, date_debut: Optional[str] = None, date_fin: Optional[str] = None, region: Optional[str] = None, district: Optional[str] = None, frequence: str = 'W') -> pandas.core.frame.DataFrame
#  |      Récupère les indicateurs épidémiologiques par période et retourne un DataFrame pandas.
#  |
#  |      Args:
#  |          date_debut: Date de début
#  |          date_fin: Date de fin
#  |          region: Région
#  |          district: District
#  |          frequence: Fréquence (W: hebdomadaire, M: mensuel)
#  |      Returns:
#  |          DataFrame pandas des indicateurs épidémiologiques
#  |
#  |  evolution(self, *args, **kwargs)
#  |      Analyse d'évolution temporelle (par semaine/mois, par sous-groupes, avec taux de croissance).
#  |      (Remplace l'ancienne méthode resume_display)
#  |
#  |      Voir : SyntheseBase.evolution pour la liste complète des paramètres et options.
#  |
#  |      Exemple :
#  |          client.evolution(by="sexe", frequence="M", taux_croissance=True)
#  |
#  |  get_alertes(self, limit: int = 10, severity: Optional[str] = None, status: Optional[str] = None, region: Optional[str] = None, district: Optional[str] = None, date_debut: Optional[str] = None, date_fin: Optional[str] = None) -> pandas.core.frame.DataFrame
#  |      Récupère les alertes selon les critères et retourne un DataFrame pandas.
#  |
#  |      Args:
#  |          limit: Nombre maximum d'alertes
#  |          severity: Sévérité (warning, critical, info)
#  |          status: Statut (active, resolved)
#  |          region: Région
#  |          district: District
#  |          date_debut: Date de début
#  |          date_fin: Date de fin
#  |
#  |      Returns:
#  |          DataFrame pandas avec les alertes
#  |
#  |  get_cache_info(self) -> Dict[str, Any]
#  |      Récupère les informations sur le cache.
#  |
#  |      Returns:
#  |          Informations sur le cache
#  |
#  |  get_cas_dengue(self, annee: int = 2025, mois: int = 7, region: Optional[str] = None, district: Optional[str] = None) -> pandas.core.frame.DataFrame
#  |      Récupère les données hebdomadaires de dengue.
#  |
#  |      Args:
#  |          annee: Année des données (défaut: année courante)
#  |          mois: Mois des données (défaut: mois courant)
#  |          region: Région pour filtrer les données
#  |          district: District pour filtrer les données
#  |
#  |      Returns:
#  |          DataFrame pandas contenant les données hebdomadaires
#  |
#  |  get_districts(self, region: Optional[str] = None) -> List[str]
#  |      Récupère la liste des districts.
#  |
#  |      Args:
#  |          region: Région pour filtrer les districts
#  |
#  |      Returns:
#  |          Liste des districts
#  |
#  |  get_profile(self) -> dengsurvab.models.User
#  |      Récupère le profil de l'utilisateur connecté.
#  |
#  |      Returns:
#  |          Informations du profil utilisateur
#  |
#  |  get_regions(self) -> List[str]
#  |      Récupère la liste des régions.
#  |
#  |      Returns:
#  |          Liste des régions disponibles
#  |
#  |  get_stats(self) -> dengsurvab.models.Statistiques
#  |      Récupère les statistiques générales.
#  |
#  |      Returns:
#  |          Statistiques du système
#  |
#  |  get_taux_hospitalisation(self, date_debut: str, date_fin: str, region: str = 'Toutes', district: str = 'Toutes') -> pandas.core.frame.DataFrame
#  |      Récupère le taux d'hospitalisation et retourne un DataFrame pandas.
#  |
#  |      Args:
#  |          date_debut: Date de début
#  |          date_fin: Date de fin
#  |          region: Région
#  |          district: District
#  |
#  |      Returns:
#  |          DataFrame pandas avec les taux d'hospitalisation
#  |
#  |  get_taux_letalite(self, date_debut: str, date_fin: str, niveau: Optional[str] = None, serotype: Optional[str] = None) -> pandas.core.frame.DataFrame
#  |      Récupère le taux de létalité et retourne un DataFrame pandas.
#  |
#  |      Args:
#  |          date_debut: Date de début
#  |          date_fin: Date de fin
#  |          niveau: Niveau d'agrégation (region, district)
#  |          serotype: Sérotype/variante à filtrer
#  |
#  |      Returns:
#  |          DataFrame pandas avec les taux de létalité
#  |
#  |  get_taux_positivite(self, date_debut: str, date_fin: str, region: Optional[str] = None, district: Optional[str] = None) -> pandas.core.frame.DataFrame
#  |      Récupère le taux de positivité et retourne un DataFrame pandas.
#  |
#  |      Args:
#  |          date_debut: Date de début
#  |          date_fin: Date de fin
#  |          region: Région
#  |          district: District
#  |
#  |      Returns:
#  |          DataFrame pandas avec les taux de positivité
#  |
#  |  graph_desc(self, *args, **kwargs)
#  |      Visualisation descriptive de la base (camemberts, barres, histogrammes).
#  |      (Remplace l'ancienne méthode resume_display)
#  |
#  |      Voir : SyntheseBase.graph_desc pour la liste complète des paramètres et options.
#  |
#  |      Exemple :
#  |          client.graph_desc(date_debut="2024-01-01", date_fin="2024-12-31")
#  |
#  |  logout(self) -> bool
#  |      Déconnecte l'utilisateur.
#  |
#  |      Returns:
#  |          True si la déconnexion a réussi
#  |
#  |  resumer(self, *args, **kwargs)
#  |      Résumé statistique et structurel de la base de données.
#  |      (Remplace l'ancienne méthode resume)
#  |
#  |      Voir : SyntheseBase.resumer pour la liste complète des paramètres et options.
#  |
#  |      Exemple :
#  |          client.resumer(annee=2024, region="Centre")
#  |
#  |  save_to_file(self, filepath: Optional[str] = None, date_debut: Optional[str] = None, date_fin: Optional[str] = None, region: Optional[str] = None, district: Optional[str] = None, limit: Optional[int] = None, page: Optional[int] = None, format: str = 'csv') -> bool
#  |      Sauvegarde les données dans un fichier.
#  |
#  |      Args:
#  |          filepath: Chemin du fichier de sortie (optionnel, utilise le répertoire courant si non fourni)
#  |          date_debut: Date de début (format YYYY-MM-DD)
#  |          date_fin: Date de fin (format YYYY-MM-DD)
#  |          region: Région à filtrer
#  |          district: District à filtrer
#  |          limit: Nombre maximum de résultats
#  |          format: Format de sortie (csv, json, xlsx, parquet)
#  |
#  |      Returns:
#  |          True si la sauvegarde a réussi
#  |
#  |      Raises:
#  |          ValueError: Si le format n'est pas supporté
#  |          IOError: En cas d'erreur d'écriture
#  |
#  |  set_cache_ttl(self, ttl: int) -> None
#  |      Définit la durée de vie du cache.
#  |
#  |      Args:
#  |          ttl: Durée de vie en secondes
#  |
#  |  update_profile(self, **kwargs) -> dengsurvab.models.User
#  |      Met à jour le profil utilisateur.
#  |
#  |      Args:
#  |          **kwargs: Champs à mettre à jour
#  |
#  |      Returns:
#  |          Profil utilisateur mis à jour
#  |
#  |  verifier_alertes(self, date_debut: Optional[str] = None, date_fin: Optional[str] = None, region: str = 'Toutes', district: str = 'Toutes') -> pandas.core.frame.DataFrame
#  |      Vérifie les alertes selon les critères et retourne un DataFrame pandas.
#  |
#  |      Args:
#  |          date_debut: Date de début
#  |          date_fin: Date de fin
#  |          region: Région
#  |          district: District
#  |
#  |      Returns:
#  |          Résultat de la vérification
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  from_env() -> 'AppiClient'
#  |      Crée une instance du client à partir des variables d'environnement.
#  |
#  |      Returns:
#  |          Instance du client configurée
#  |
#  |      Raises:
#  |          ConfigurationError: Si les variables requises sont manquantes
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
cl.alertes(limit=20)
# Out:
#     ID                Email  Région District      Type         Destinataire  \
# 0   18  yamsaid74@gmail.com  Centre     Tous  critical  yamsaid74@gmail.com
# 1   17  yamsaid74@gmail.com  Centre     Tous  critical  yamsaid74@gmail.com
# 2   16  yamsaid74@gmail.com  Centre     Tous  critical  yamsaid74@gmail.com
# 3   15  yamsaid74@gmail.com  Centre     Tous  critical  yamsaid74@gmail.com
# 4   14  yamsaid74@gmail.com  Centre     Tous  critical  yamsaid74@gmail.com
# 5   13  yamsaid74@gmail.com  Centre     Tous  critical  yamsaid74@gmail.com
# 6   12  yamsaid74@gmail.com  Toutes     Tous  critical  yamsaid74@gmail.com
# 7   11  yamsaid74@gmail.com  Toutes     Tous  critical  yamsaid74@gmail.com
# 8   10  yamsaid74@gmail.com  Toutes     Tous  critical  yamsaid74@gmail.com
# 9    9  yamsaid74@gmail.com  Toutes     Tous  critical  yamsaid74@gmail.com
# 10   8  yamsaid74@gmail.com  Centre     Tous  critical  yamsaid74@gmail.com
# 11   7  yamsaid74@gmail.com  Centre     Tous  critical  yamsaid74@gmail.com
# 12   6  yamsaid74@gmail.com  Toutes     Tous  critical  yamsaid74@gmail.com
# 13   5  yamsaid74@gmail.com  Toutes     Tous  critical  yamsaid74@gmail.com
# 14   4  yamsaid74@gmail.com  Centre     Tous  critical  yamsaid74@gmail.com
# 15   3  yamsaid74@gmail.com  Centre     Tous  critical  yamsaid74@gmail.com
# 16   2  yamsaid74@gmail.com  Toutes     Tous  critical  yamsaid74@gmail.com
# 17   1  yamsaid74@gmail.com  Toutes     Tous  critical  yamsaid74@gmail.com
#
#     Sévérité Statut                                            Message  \
# 0   critical  Actif             Taux de décès élevé: 3.41% (seuil: 1%)
# 1   critical  Actif      Taux de positivité élevé: 63.64% (seuil: 10%)
# 2   critical  Actif             Taux de décès élevé: 3.41% (seuil: 1%)
# 3   critical  Actif      Taux de positivité élevé: 63.64% (seuil: 10%)
# 4   critical  Actif             Taux de décès élevé: 3.41% (seuil: 1%)
# 5   critical  Actif      Taux de positivité élevé: 63.64% (seuil: 10%)
# 6   critical  Actif      Taux de positivité élevé: 63.64% (seuil: 10%)
# 7   critical  Actif      Taux de positivité élevé: 63.64% (seuil: 10%)
# 8   critical  Actif      Taux de positivité élevé: 63.64% (seuil: 10%)
# 9   critical  Actif      Taux de positivité élevé: 63.64% (seuil: 10%)
# 10  critical  Actif             Taux de décès élevé: 3.41% (seuil: 1%)
# 11  critical  Actif      Taux de positivité élevé: 63.64% (seuil: 10%)
# 12  critical  Actif  Taux d'hospitalisation élevé: 34.09% (seuil: 10%)
# 13  critical  Actif      Taux de positivité élevé: 63.64% (seuil: 10%)
# 14  critical  Actif   Taux d'hospitalisation élevé: 28.25% (seuil: 7%)
# 15  critical  Actif      Taux de positivité élevé: 51.82% (seuil: 10%)
# 16  critical  Actif  Taux d'hospitalisation élevé: 32.32% (seuil: 10%)
# 17  critical  Actif      Taux de positivité élevé: 62.63% (seuil: 10%)
#
#               Date de création
# 0   2025-07-09T23:57:20.835977
# 1   2025-07-09T23:57:20.496669
# 2   2025-07-09T23:52:41.786887
# 3   2025-07-09T23:52:41.445351
# 4   2025-07-09T23:46:04.957941
# 5   2025-07-09T23:46:04.619160
# 6   2025-07-09T23:44:09.937382
# 7   2025-07-09T23:42:51.308297
# 8   2025-07-09T23:38:19.124221
# 9   2025-07-09T23:37:03.205950
# 10  2025-07-09T22:22:28.332005
# 11  2025-07-09T22:22:27.997014
# 12  2025-07-09T22:21:55.285629
# 13  2025-07-09T22:21:55.116426
# 14  2025-07-09T08:28:20.034821
# 15  2025-07-09T08:28:19.868452
# 16  2025-07-08T00:32:19.122541
# 17  2025-07-08T00:32:18.957838
